# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("netflix_titles.csv")
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
ratings= df["rating"].to_numpy()
types= df["type"].to_numpy()
year_of_release= df["release_year"].to_numpy()
duration= df["duration"].to_numpy()
listed= df["listed_in"].to_numpy()
show_title= df["title"].to_numpy()
show_directors= df["director"].to_numpy()
casting= df["cast"].to_numpy()
show_region= df["country"].to_numpy()
show_dates= df["date_added"].to_numpy()

# %%
print("Ratings:", ratings)
print("Types:", types)
print("Year:", year_of_release)
print("Duration:", duration)
print("Listed in:", listed)
# Out:
# Ratings: ['PG-13' 'TV-MA' 'TV-MA' ... 'R' 'PG' 'TV-14']
# Types: ['Movie' 'TV Show' 'TV Show' ... 'Movie' 'Movie' 'Movie']
# Year: [2020 2021 2021 ... 2009 2006 2015]
# Duration: ['90 min' '2 Seasons' '1 Season' ... '88 min' '88 min' '111 min']
# Listed in: ['Documentaries' 'International TV Shows, TV Dramas, TV Mysteries'
#  'Crime TV Shows, International TV Shows, TV Action & Adventure' ...
#  'Comedies, Horror Movies' 'Children & Family Movies, Comedies'
#  'Dramas, International Movies, Music & Musicals']

# %%
np.array(df["release_year"])
df.values
df.to_numpy()
# Out:
# array([['s1', 'Movie', 'Dick Johnson Is Dead', ..., '90 min',
#         'Documentaries',
#         'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'],
#        ['s2', 'TV Show', 'Blood & Water', ..., '2 Seasons',
#         'International TV Shows, TV Dramas, TV Mysteries',
#         'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.'],
#        ['s3', 'TV Show', 'Ganglands', ..., '1 Season',
#         'Crime TV Shows, International TV Shows, TV Action & Adventure',
#         'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.'],
#        ...,
#        ['s8805', 'Movie', 'Zombieland', ..., '88 min',
#         'Comedies, Horror Movies',
# ...

# %%
np.unique(year_of_release)
np.arange(year_of_release.min(), year_of_release.max())
# Out:
# array([1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935,
#        1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946,
#        1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# Handling missing values

# %% [markdown]
# 1) Detecting missing values

# %%
dtct_missing_ratings= pd.isna(ratings)
dtct_missing_types= pd.isna(types)
dtct_missing_years= np.isnan(year_of_release)
dtct_missing_durations= pd.isna(duration)
dtct_missing_list= pd.isna(listed)
dtct_missing_title= pd.isna(show_title)
dtct_missing_directors= pd.isna(show_directors)
dtct_missing_cast= pd.isna(casting)
dtct_missing_country= pd.isna(show_region)
dtct_missing_dates= pd.isna(show_dates)

# %%
dtct_missing_directors
# Out:
# array([False,  True, False, ..., False, False, False], shape=(8807,))

# %% [markdown]
# 2. Counting missing values

# %%
np.sum(dtct_missing_directors)
# Out:
# np.int64(2634)

# %% [markdown]
# 3. Removing Missing Values

# %%
# for single column
df_clean = df.dropna(subset=["director"])
df_clean
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
# for every column
df_clean_all= df.dropna()
df_clean_all
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %% [markdown]
# Filtering and Boolean Masking

# %% [markdown]
# 1. Movies released after 2016

# %%
movies_post2016= year_of_release[year_of_release > 2016]

# %%
np.count_nonzero(movies_post2016)
# Out:
# np.int64(4754)

# %% [markdown]
# 2. Boolean masks

# %%
masks= year_of_release>= 2016
df[masks]
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre              NaN
# 8797   s8798  TV Show                  Zak Storm              NaN
# 8803   s8804  TV Show                Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# 3. Netflix Movies Only

# %%
movies_only= types== "Movie"
df[movies_only]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# Statistical operations

# %% [markdown]
# 1. Release year statistics

# %%
mean_year= np.mean(year_of_release)
median_year=np.median(year_of_release)
min_year=np.min(year_of_release)
max_year=np.max(year_of_release)
std_year=np.std(year_of_release)

# %%
min_year
# Out:
# np.int64(1925)

# %%
var_year= np.var(year_of_release)
range_year= np.max(year_of_release)-np.min(year_of_release)

# %%
range_year
# Out:
# np.int64(96)

# %% [markdown]
# Frequency and Counting operations

# %% [markdown]
# 1. Counting Movies vs TV shows

# %%
np.unique(types, return_counts=True)
# Out:
# (array(['Movie', 'TV Show'], dtype=object), array([6131, 2676]))

# %% [markdown]
# 2. Counting contents per year

# %%
unique_years ,counts= np.unique(year_of_release, return_counts=True)
unique_years
# Out:
# array([1925, 1942, 1943, 1944, 1945, 1946, 1947, 1954, 1955, 1956, 1958,
#        1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
counts
# Out:
# array([   1,    2,    3,    3,    4,    2,    1,    2,    3,    2,    3,
#           1,    4,    1,    3,    2,    2,    2,    1,    5,    3,    2,
#           2,    5,    5,   10,    7,    7,    9,    7,    7,   11,   11,
#          13,   17,   11,   12,   10,   13,    8,   18,   16,   22,   17,
#          23,   28,   22,   25,   24,   38,   36,   39,   37,   45,   51,
#          61,   64,   80,   96,   88,  136,  152,  194,  185,  237,  288,
#         352,  560,  902, 1032, 1147, 1030,  953,  592])

# %% [markdown]
# String Operations

# %% [markdown]
# 1. Converting text to numpy string array

# %%
countries= df["country"].dropna().to_numpy(dtype=str)
countries
# Out:
# array(['United States', 'South Africa', 'India', ..., 'United States',
#        'United States', 'India'], shape=(7976,), dtype='<U123')

# %%
indian_movies= np.count_nonzero((df["type"]=="Movie") & df["country"].str.contains("India", na=False))
indian_movies
# Out:
# np.int64(962)

# %% [markdown]
# 2. String Contains

# %%
np.char.find(countries, "India")>=0
# Out:
# array([False, False,  True, ..., False, False,  True], shape=(7976,))

# %% [markdown]
# 3. Upper/ Lower case

# %%
np.char.upper(countries)
# Out:
# array(['UNITED STATES', 'SOUTH AFRICA', 'INDIA', ..., 'UNITED STATES',
#        'UNITED STATES', 'INDIA'], shape=(7976,), dtype='<U123')

# %% [markdown]
# Sorting Operations

# %% [markdown]
# 1. Sorting by year of release

# %%
np.sort(year_of_release )
# Out:
# array([1925, 1942, 1942, ..., 2021, 2021, 2021], shape=(8807,))

# %% [markdown]
# 2. Sort with indices

# %%
indices= np.argsort(year_of_release)
df.iloc[indices]
# Out:
#      show_id     type                               title  \
# 4250   s4251  TV Show   Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                      Prelude to War
# 8205   s8206    Movie                The Battle of Midway
# 8739   s8740    Movie  Why We Fight: The Battle of Russia
# 8763   s8764    Movie     WWII: Report from the Aleutians
# ...      ...      ...                                 ...
# 3         s4  TV Show               Jailbirds New Orleans
# 2         s3  TV Show                           Ganglands
# 18       s19    Movie                           Intrusion
# 1         s2  TV Show                       Blood & Water
# 68       s69    Movie                          Schumacher
#
#                                                director  \
# 4250                                                NaN
# 7790                                        Frank Capra
# 8205                                          John Ford
# ...

# %%
sorted_years= year_of_release[indices]
sorted_years
# Out:
# array([1925, 1942, 1942, ..., 2021, 2021, 2021], shape=(8807,))

# %% [markdown]
# Mathematical and Logical operations

# %% [markdown]
# 1. Compare years

# %%
year_of_release>2016
# Out:
# array([ True,  True,  True, ..., False, False, False], shape=(8807,))

# %%
year_of_release== 2020
# Out:
# array([ True, False, False, ..., False, False, False], shape=(8807,))

# %% [markdown]
# 2. Logical Operations

# %%
np.logical_and(year_of_release>2010, year_of_release<2020)
# Out:
# array([False, False, False, ..., False, False,  True], shape=(8807,))

# %% [markdown]
# Vectorized Operations(no loops)

# %% [markdown]
# 1. Add year_of_release offset

# %%
year_of_release+1
# Out:
# array([2021, 2022, 2022, ..., 2010, 2007, 2016], shape=(8807,))

# %% [markdown]
# 2. Age of content

# %%
content_age= 2026- year_of_release
content_age
# Out:
# array([ 6,  5,  5, ..., 17, 20, 11], shape=(8807,))

# %% [markdown]
# Indexing and slicing

# %% [markdown]
# 1. First 15 entries

# %%
year_of_release[:15]
# Out:
# array([2020, 2021, 2021, 2021, 2021, 2021, 2021, 1993, 2021, 2021, 2021,
#        2021, 2021, 2021, 2021])

# %% [markdown]
# 2. Every 5th entry

# %%
year_of_release[::5]
# Out:
# array([2020, 2021, 2021, ..., 2015, 2012, 2006], shape=(1762,))

# %% [markdown]
# Aggregation by Categories (Hybrid NumPy Logic)

# %%
movies_per_year= year_of_release[movies_only]
np.unique(movies_per_year, return_counts=True)
# Out:
# (array([1942, 1943, 1944, 1945, 1946, 1947, 1954, 1955, 1956, 1958, 1959,
#         1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#         1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#         1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#         1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#         2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#         2015, 2016, 2017, 2018, 2019, 2020, 2021]),
#  array([  2,   3,   3,   3,   1,   1,   2,   3,   2,   3,   1,   4,   1,
#           3,   1,   2,   2,   1,   4,   3,   2,   2,   5,   4,  10,   6,
#           7,   9,   6,   7,  10,  11,  12,  17,  11,  12,   9,  11,   8,
#          16,  15,  19,  16,  20,  24,  20,  23,  21,  34,  32,  32,  33,
#          40,  44,  51,  55,  67,  82,  74, 113, 118, 154, 145, 173, 225,
#         264, 398, 658, 767, 767, 633, 517, 277]))

# %% [markdown]
# Correlation & Relationships

# %%
np.corrcoef(year_of_release, content_age)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %% [markdown]
# Broadcasting

# %%
year_of_release- np.mean(year_of_release)
# Out:
# array([ 5.81980243,  6.81980243,  6.81980243, ..., -5.18019757,
#        -8.18019757,  0.81980243], shape=(8807,))

# %% [markdown]
# Random sampling

# %%
# unique indeces
sample_index= np.random.choice(year_of_release, size=10, replace=False)
sample_index
# Out:
# array([2016, 2018, 2021, 2014, 2020, 2011, 2015, 2008, 2016, 2018])

# %%
# unique values
sample_value= np.random.choice(unique_years, size=10, replace=False)
sample_value
# Out:
# array([2016, 1956, 2003, 1964, 1999, 2015, 1981, 1970, 2000, 2021])

# %% [markdown]
# Reshaping and structuring

# %%
year_of_release.reshape(-1, 1)
# Out:
# array([[2020],
#        [2021],
#        [2021],
#        ...,
#        [2009],
#        [2006],
#        [2015]], shape=(8807, 1))

# %%
np.column_stack((year_of_release, content_age))
# Out:
# array([[2020,    6],
#        [2021,    5],
#        [2021,    5],
#        ...,
#        [2009,   17],
#        [2006,   20],
#        [2015,   11]], shape=(8807, 2))

# %% [markdown]
# Performance Optimization

# %%
ages= []
for y in year_of_release:
    ages.append(2026-y)

# %%
ages
# Out:
# [np.int64(6),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(33),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(6),
#  np.int64(6),
#  np.int64(5),
#  np.int64(5),
#  np.int64(5),
#  np.int64(8),
#  np.int64(30),
#  np.int64(5),
#  np.int64(28),
#  np.int64(5),
#  np.int64(29),
#  np.int64(16),
#  np.int64(13),
#  np.int64(13),
#  np.int64(5),
#  np.int64(5),
#  np.int64(6),
#  np.int64(5),
#  np.int64(6),
#  np.int64(5),
#  np.int64(5),
#  np.int64(8),
#  np.int64(9),
#  np.int64(5),
#  np.int64(5),
#  np.int64(51),
#  np.int64(48),
#  np.int64(43),
#  np.int64(39),
#  np.int64(5),
#  np.int64(14),
#  np.int64(6),
#  np.int64(25),
#  np.int64(5),
#  np.int64(12),
#  np.int64(24),
#  np.int64(23),
#  np.int64(22),
#  np.int64(25),
#  np.int64(5),
#  np.int64(15),
#  np.int64(18),
#  np.int64(17),
#  np.int64(19),
#  np.int64(16),
# ...
