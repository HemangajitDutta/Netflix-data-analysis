# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 1. Percentage-based understanding

# %%
# percentage of missing value per column
df.isnull().mean()* 100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# 2. Cardinality check

# %%
# calculating the unique values per column
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# 3. Column-level uniqueness

# %%
# no of unique countries
df["country"].nunique()
# Out:
# 748

# %% [markdown]
# 4. Relationship strength

# %%
df["release_year"].corr(2026 - df["release_year"])
# Out:
# np.float64(-0.9999999999999982)

# %% [markdown]
# 5. Duplicate inspection

# %%
# calculation of the number of duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 6. Memory usage understanding

# %%
df.memory_usage()
# Out:
# Index             132
# show_id         70456
# type            70456
# title           70456
# director        70456
# cast            70456
# country         70456
# date_added      70456
# release_year    70456
# rating          70456
# duration        70456
# listed_in       70456
# description     70456
# dtype: int64

# %% [markdown]
# 7. Text length insight

# %%
# distribution of title lengths
df["title"].str.len().describe()
# Out:
# count    8807.000000
# mean       17.725786
# std        10.630855
# min         1.000000
# 25%        10.000000
# 50%        15.000000
# 75%        23.000000
# max       104.000000
# Name: title, dtype: float64

# %%
# distribution of description lengths
df["description"].str.len().describe()
# Out:
# count    8807.000000
# mean      143.303281
# std        10.334959
# min        61.000000
# 25%       140.000000
# 50%       146.000000
# 75%       149.000000
# max       248.000000
# Name: description, dtype: float64

# %% [markdown]
# 8. Value proportions

# %%
# percentage of movies vs tv shows
df["type"].value_counts(normalize=True)
# Out:
# type
# Movie      0.696151
# TV Show    0.303849
# Name: proportion, dtype: float64

# %% [markdown]
# 9. Rare values detection

# %%
# least rating detection
df["rating"].value_counts().tail()
# Out:
# rating
# NC-17     3
# UR        3
# 74 min    1
# 84 min    1
# 66 min    1
# Name: count, dtype: int64

# %% [markdown]
# 10. Index sanity check

# %%
# understanding row indexing
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %% [markdown]
# 11. Null-pattern scan

# %%
# checking the rows containing missing values
df[df.isnull().any(axis=1)]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...
